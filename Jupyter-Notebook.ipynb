# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Merna Hussien** \
# Data scientist

# %% [markdown]
# *I'm interested in data science because I love to investigate in problems and learning new things*

# %% [markdown]
# ### the summation of two numbers

# %%
10+20
# Out:
# 30

# %% [markdown]
# www.IBM.com \
# *one.\
# *two.\
# *three.\
# ![R.jpg](attachment:58655ff5-8636-4ef8-b4a5-26a8f9484d2c.jpg)
